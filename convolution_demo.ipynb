# %%
import numpy as np
import mkl_fft
from functools import partial
import copy

# custom modules
from filters import *
from convolution import *
from core import *
from scatutils import *
from test_scatnet import *

import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Padding

# %%
test_pad_signal()
# Out:
# Initial signal: (3, 2), padded signal: (8, 2)
# [[ 1 10]
#  [ 2 20]
#  [ 3 30]]
#
#  zero padding
# [[ 0  0]
#  [ 0  0]
#  [ 1 10]
#  [ 2 20]
#  [ 3 30]
#  [ 0  0]
#  [ 0  0]
#  [ 0  0]]
#
#  symm padding
# [[ 2 20]
#  [ 1 10]
#  [ 1 10]
#  [ 2 20]
#  [ 3 30]
#  [ 3 30]
#  [ 2 20]
#  [ 1 10]]
#
#  per padding
# [[ 2 20]
#  [ 3 30]
#  [ 1 10]
#  [ 2 20]
#  [ 3 30]
#  [ 1 10]
#  [ 2 20]
#  [ 3 30]]

# %% [markdown]
# # Unpadding

# %%
test_unpad_signal()
# Out:
#  Initial signal: (16, 2)
# [[  0   0]
#  [  1  10]
#  [  2  20]
#  [  3  30]
#  [  4  40]
#  [  5  50]
#  [  6  60]
#  [  7  70]
#  [  8  80]
#  [  9  90]
#  [ 10 100]
#  [ 11 110]
#  [ 12 120]
#  [ 13 130]
#  [ 14 140]
#  [ 15 150]]
#
#  Unpadded signal: (11, 2), N_unpadded = 11, center = 0, resolution = 0
# [[  0   0]
#  [  1  10]
#  [  2  20]
#  [  3  30]
#  [  4  40]
#  [  5  50]
#  [  6  60]
#  [  7  70]
#  [  8  80]
#  [  9  90]
#  [ 10 100]]
#
#  Unpadded signal: (11, 2), N_unpadded = 11, center = 1, resolution = 0
# [[  2  20]
#  [  3  30]
#  [  4  40]
#  [  5  50]
#  [  6  60]
#  [  7  70]
#  [  8  80]
#  [  9  90]
#  [ 10 100]
#  [ 11 110]
#  [ 12 120]]
#
#  Unpadded signal: (5, 2), N_unpadded = 11, center = 1, resolution = 1
# [[ 5 50]
#  [ 6 60]
#  [ 7 70]
#  [ 8 80]
#  [ 9 90]]

# %% [markdown]
# # Convolution

# %%
test_conv_sub_1d(ds=4)
# Out:
# /home/julia/anaconda3/envs/tf15/lib/python3.5/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
